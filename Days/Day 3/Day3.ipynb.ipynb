# %%
#import library pandan
#syntax for import (import library name as pd)
import pandas as pd

# %%
#read data from google colab
data = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/nimca.pptx (9)).xlsx")

# %%
data.head()
# Out:
#            RAW DATA — 20_Marketing (Original Source)           Unnamed: 1  \
# 0  DO NOT MODIFY — preserved exactly as supplied ...                  NaN
# 1                                        Campaign_ID           Start_Date
# 2                                            CMP0268  2026-02-24 00:00:00
# 3                                            CMP0077  2026-06-13 00:00:00
# 4                                            CMP0207  2026-05-11 00:00:00
#
#   Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5   Unnamed: 6
# 0        NaN        NaN        NaN        NaN          NaN
# 1    Channel     Region     Budget      Leads  Conversions
# 2     Search  Mogadishu     1902.8        258           58
# 3        NaN  Mogadishu    2408.15        408           89
# 4        NaN    Kismayo    2635.33        573          100

# %% [markdown]
# Reading last five rows using tail function

# %%
data.tail()
# Out:
#     RAW DATA — 20_Marketing (Original Source)           Unnamed: 1  \
# 297                                   CMP0277  2025-03-04 00:00:00
# 298                                   CMP0006  2025-12-16 00:00:00
# 299                                   CMP0226  2025-03-11 00:00:00
# 300                                   CMP0209  2026-07-12 00:00:00
# 301                                   CMP0037  2025-08-18 00:00:00
#
#        Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6
# 297  Social Media     Baidoa    3342.91        599        124
# 298  Social Media  Mogadishu    2877.39        463        NaN
# 299         Radio     Bosaso    3509.09        714         42
# 300         Email   Hargeisa    3794.91        442         77
# 301    Influencer        NaN    4177.41        427         69

# %%
data.sample()
# Out:
#    RAW DATA — 20_Marketing (Original Source)           Unnamed: 1 Unnamed: 2  \
# 85                                   CMP0086  2025-09-10 00:00:00     Search
#
#    Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6
# 85  Mogadishu    1245.05        135         28

# %% [markdown]
# Data columns

# %%
data.columns
# Out:
# Index(['RAW DATA — 20_Marketing (Original Source)', 'Unnamed: 1', 'Unnamed: 2',
#        'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6'],
#       dtype='object')

# %% [markdown]
# this diply data type

# %%
data.dtypes
# Out:
# RAW DATA — 20_Marketing (Original Source)    object
# Unnamed: 1                                   object
# Unnamed: 2                                   object
# Unnamed: 3                                   object
# Unnamed: 4                                   object
# Unnamed: 5                                   object
# Unnamed: 6                                   object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 302 entries, 0 to 301
# Data columns (total 7 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   RAW DATA — 20_Marketing (Original Source)  287 non-null    object
#  1   Unnamed: 1                                 286 non-null    object
#  2   Unnamed: 2                                 285 non-null    object
#  3   Unnamed: 3                                 286 non-null    object
#  4   Unnamed: 4                                 286 non-null    object
#  5   Unnamed: 5                                 280 non-null    object
#  6   Unnamed: 6                                 286 non-null    object
# dtypes: object(7)
# memory usage: 16.6+ KB

# %% [markdown]
# Disply  the discrip of statistics using discrib function

# %%
data.describe()
# Out:
#        RAW DATA — 20_Marketing (Original Source)           Unnamed: 1  \
# count                                        287                  286
# unique                                       279                  213
# top                                      CMP0199  2026-06-03 00:00:00
# freq                                           2                    4
#
#        Unnamed: 2 Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6
# count         285        286      286.00         280         286
# unique          9         11      279.00         240         153
# top        Search  Mogadishu     3453.41         350          32
# freq           84         92        2.00           4           6

# %%
data.describe(include="all")
# Out:
#        RAW DATA — 20_Marketing (Original Source)           Unnamed: 1  \
# count                                        287                  286
# unique                                       279                  213
# top                                      CMP0199  2026-06-03 00:00:00
# freq                                           2                    4
#
#        Unnamed: 2 Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6
# count         285        286      286.00         280         286
# unique          9         11      279.00         240         153
# top        Search  Mogadishu     3453.41         350          32
# freq           84         92        2.00           4           6

# %%
data.isnull().sum()
# Out:
# RAW DATA — 20_Marketing (Original Source)    15
# Unnamed: 1                                   16
# Unnamed: 2                                   17
# Unnamed: 3                                   16
# Unnamed: 4                                   16
# Unnamed: 5                                   22
# Unnamed: 6                                   16
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(7)

# %%
print("Data Info After Cleaning:")
data.info()

print("\nMissing Values:")
print(data.isnull().sum())

print("\nDuplicate Rows:")
print(data.duplicated().sum())
# Out:
# Data Info After Cleaning:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 302 entries, 0 to 301
# Data columns (total 7 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   RAW DATA — 20_Marketing (Original Source)  287 non-null    object
#  1   Unnamed: 1                                 286 non-null    object
#  2   Unnamed: 2                                 285 non-null    object
#  3   Unnamed: 3                                 286 non-null    object
#  4   Unnamed: 4                                 286 non-null    object
#  5   Unnamed: 5                                 280 non-null    object
#  6   Unnamed: 6                                 286 non-null    object
# dtypes: object(7)
# memory usage: 16.6+ KB
#
# Missing Values:
# RAW DATA — 20_Marketing (Original Source)    15
# Unnamed: 1                                   16
# ...

# %%
data.head(10)
# Out:
#            RAW DATA — 20_Marketing (Original Source)           Unnamed: 1  \
# 0  DO NOT MODIFY — preserved exactly as supplied ...                  NaN
# 1                                        Campaign_ID           Start_Date
# 2                                            CMP0268  2026-02-24 00:00:00
# 3                                            CMP0077  2026-06-13 00:00:00
# 4                                            CMP0207  2026-05-11 00:00:00
# 5                                                NaN  2025-12-14 00:00:00
# 6                                            CMP0089  2025-03-16 00:00:00
# 7                                            CMP0098  2025-04-25 00:00:00
# 8                                            CMP0206  2026-06-12 00:00:00
# 9                                            CMP0094  2026-05-04 00:00:00
#
#      Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5   Unnamed: 6
# 0           NaN        NaN        NaN        NaN          NaN
# ...

# %%
data = pd.read_excel(
    "/content/drive/MyDrive/Colab Notebooks/nimca.pptx (9)).xlsx",
    header=1
)

# %%
data.head()
# Out:
#   DO NOT MODIFY — preserved exactly as supplied by the lecturer.  \
# 0                                        Campaign_ID
# 1                                            CMP0268
# 2                                            CMP0077
# 3                                            CMP0207
# 4                                                NaN
#
#             Unnamed: 1    Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0           Start_Date       Channel     Region     Budget      Leads
# 1  2026-02-24 00:00:00        Search  Mogadishu     1902.8        258
# 2  2026-06-13 00:00:00           NaN  Mogadishu    2408.15        408
# 3  2026-05-11 00:00:00           NaN    Kismayo    2635.33        573
# 4  2025-12-14 00:00:00  Social Media    Kismayo    3036.06        350
#
#     Unnamed: 6
# 0  Conversions
# 1           58
# 2           89
# 3          100
# 4           61

# %%
data.columns
# Out:
# Index(['DO NOT MODIFY — preserved exactly as supplied by the lecturer.',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 7 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   DO NOT MODIFY — preserved exactly as supplied by the lecturer.  286 non-null    object
#  1   Unnamed: 1                                                      286 non-null    object
#  2   Unnamed: 2                                                      285 non-null    object
#  3   Unnamed: 3                                                      286 non-null    object
#  4   Unnamed: 4                                                      286 non-null    object
#  5   Unnamed: 5                                                      280 non-null    object
#  6   Unnamed: 6                                                      286 non-null    object
# dtypes: object(7)
# memory usage: 16.6+ KB

# %%
data = pd.read_excel(
    "/content/drive/MyDrive/Colab Notebooks/Marketing-Data-Analysis..xlsx",
    header=1
)

# %%
data.head()
# Out:
#   DO NOT MODIFY — preserved exactly as supplied by the lecturer.  \
# 0                                        Campaign_ID
# 1                                            CMP0268
# 2                                            CMP0077
# 3                                            CMP0207
# 4                                                NaN
#
#             Unnamed: 1    Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0           Start_Date       Channel     Region     Budget      Leads
# 1  2026-02-24 00:00:00        Search  Mogadishu     1902.8        258
# 2  2026-06-13 00:00:00           NaN  Mogadishu    2408.15        408
# 3  2026-05-11 00:00:00           NaN    Kismayo    2635.33        573
# 4  2025-12-14 00:00:00  Social Media    Kismayo    3036.06        350
#
#     Unnamed: 6
# 0  Conversions
# 1           58
# 2           89
# 3          100
# 4           61

# %%
data.tail()
# Out:
#     DO NOT MODIFY — preserved exactly as supplied by the lecturer.  \
# 296                                            CMP0277
# 297                                            CMP0006
# 298                                            CMP0226
# 299                                            CMP0209
# 300                                            CMP0037
#
#               Unnamed: 1    Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 296  2025-03-04 00:00:00  Social Media     Baidoa    3342.91        599
# 297  2025-12-16 00:00:00  Social Media  Mogadishu    2877.39        463
# 298  2025-03-11 00:00:00         Radio     Bosaso    3509.09        714
# 299  2026-07-12 00:00:00         Email   Hargeisa    3794.91        442
# 300  2025-08-18 00:00:00    Influencer        NaN    4177.41        427
#
#     Unnamed: 6
# 296        124
# 297        NaN
# 298         42
# 299         77
# 300         69

# %%
data.shape
# Out:
# (301, 7)

# %%
data.columns
# Out:
# Index(['DO NOT MODIFY — preserved exactly as supplied by the lecturer.',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 7 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   DO NOT MODIFY — preserved exactly as supplied by the lecturer.  286 non-null    object
#  1   Unnamed: 1                                                      286 non-null    object
#  2   Unnamed: 2                                                      285 non-null    object
#  3   Unnamed: 3                                                      286 non-null    object
#  4   Unnamed: 4                                                      286 non-null    object
#  5   Unnamed: 5                                                      280 non-null    object
#  6   Unnamed: 6                                                      286 non-null    object
# dtypes: object(7)
# memory usage: 16.6+ KB

# %%
import pandas as pd

# %%
data=pd.read_excel("/content/Excel data.xlsx")

# %%
data.head()
# Out:
#   Campaign_ID           Start_Date       Channel     Region   Budget Leads  \
# 0     CMP0268  2026-02-24 00:00:00        Search  Mogadishu  1902.80   258
# 1     CMP0077  2026-06-13 00:00:00           NaN  Mogadishu  2408.15   408
# 2     CMP0207  2026-05-11 00:00:00           NaN    Kismayo  2635.33   573
# 3         NaN  2025-12-14 00:00:00  Social Media    Kismayo  3036.06   350
# 4     CMP0089  2025-03-16 00:00:00  Social Media   Hargeisa  4857.89   742
#
#   Conversions
# 0          58
# 1          89
# 2         100
# 3          61
# 4         131

# %%
data.rename(columns={"old_column_name": "new_column_name"}, inplace=True)

# %%
data.rename(columns={"colum": "column"}, inplace=True)

# %%
old_value = "colum"
new_value = "column"

data.rename(columns={old_value: new_value}, inplace=True)

# %%
data.columns
# Out:
# Index(['Campaign_ID', 'Start_Date', 'Channel', 'Region', 'Budget', 'Leads',
#        'Conversions'],
#       dtype='object')

# %%
columns=["student_ID"]

# %%
data.isnull().sum()
# Out:
# Campaign_ID    15
# Start_Date     15
# Channel        16
# Region         15
# Budget         15
# Leads          21
# Conversions    15
# dtype: int64

# %%
data[data.isnull().any(axis=1)]
# Out:
#     Campaign_ID           Start_Date       Channel     Region   Budget Leads  \
# 1       CMP0077  2026-06-13 00:00:00           NaN  Mogadishu  2408.15   408
# 2       CMP0207  2026-05-11 00:00:00           NaN    Kismayo  2635.33   573
# 3           NaN  2025-12-14 00:00:00  Social Media    Kismayo  3036.06   350
# 5       CMP0098  2025-04-25 00:00:00    Influencer        NaN  2904.04  2013
# 11      CMP0082  2025-08-19 00:00:00        Search        NaN  4275.45   604
# ..          ...                  ...           ...        ...      ...   ...
# 287     CMP0012  2025-05-25 00:00:00  Social Media        NaN  2109.18   251
# 290     CMP0222  2026-07-23 00:00:00         Radio  Mogadishu   609.81   NaN
# 291     CMP0142  2025-06-23 00:00:00  Social Media        NaN  4216.83   508
# 296     CMP0006  2025-12-16 00:00:00  Social Media  Mogadishu  2877.39   463
# 299     CMP0037  2025-08-18 00:00:00    Influencer        NaN  4177.41   427
#
#     Conversions
# 1            89
# ...

# %%
data[data.isnull().any(axis=1)]
# Out:
#     Campaign_ID           Start_Date       Channel     Region   Budget Leads  \
# 1       CMP0077  2026-06-13 00:00:00           NaN  Mogadishu  2408.15   408
# 2       CMP0207  2026-05-11 00:00:00           NaN    Kismayo  2635.33   573
# 3           NaN  2025-12-14 00:00:00  Social Media    Kismayo  3036.06   350
# 5       CMP0098  2025-04-25 00:00:00    Influencer        NaN  2904.04  2013
# 11      CMP0082  2025-08-19 00:00:00        Search        NaN  4275.45   604
# ..          ...                  ...           ...        ...      ...   ...
# 287     CMP0012  2025-05-25 00:00:00  Social Media        NaN  2109.18   251
# 290     CMP0222  2026-07-23 00:00:00         Radio  Mogadishu   609.81   NaN
# 291     CMP0142  2025-06-23 00:00:00  Social Media        NaN  4216.83   508
# 296     CMP0006  2025-12-16 00:00:00  Social Media  Mogadishu  2877.39   463
# 299     CMP0037  2025-08-18 00:00:00    Influencer        NaN  4177.41   427
#
#     Conversions
# 1            89
# ...

# %%
data.isnull().sum().sum()
# Out:
# np.int64(112)

# %%
data.dtypes
# Out:
# Campaign_ID     object
# Start_Date      object
# Channel         object
# Region          object
# Budget         float64
# Leads           object
# Conversions     object
# dtype: object

# %%
data['Start_Date'] =pd.to_datetime(data['Start_Date'], errors='coerce')

# %%
data['Budget'] =pd.to_numeric(data['Budget'], errors='coerce')

# %%
data.dtypes
# Out:
# Campaign_ID     object
# Start_Date       int64
# Channel         object
# Region          object
# Budget         float64
# Leads           object
# Conversions     object
# dtype: object

# %%
data
